# %%
import pandas as pd
df=pd.read_csv('Traffic_Crashes_Resulting_in_Injury_20250307.csv')
df
# Out:
# c:\Users\asaav\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (3,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        unique_id  cnn_intrsctn_fkey  cnn_sgmt_fkey case_id_pkey  tb_latitude  \
# 0          82049         20208000.0      8087000.0  2.30042e+08    37.734019
# 1          82166         25723000.0       805000.0  2.30112e+08    37.762886
# 2          41951         32862000.0      7826101.0  3.49192e+06    37.768636
# 3          48546         23904000.0            NaN  1.90524e+08    37.780363
# 4          35692         26705000.0            NaN  1.70391e+08    37.804146
# ...          ...                ...            ...          ...          ...
# 61224      83499         23514000.0      8517000.0    230530588    37.745446
# 61225      85663         24120000.0            NaN    240327541    37.755971
# ...

# %%
df.columns
# Out:
# Index(['unique_id', 'cnn_intrsctn_fkey', 'cnn_sgmt_fkey', 'case_id_pkey',
#        'tb_latitude', 'tb_longitude', 'geocode_source', 'geocode_location',
#        'collision_datetime', 'collision_date', 'collision_time',
#        'accident_year', 'month', 'day_of_week', 'time_cat', 'juris',
#        'officer_id', 'reporting_district', 'beat_number', 'primary_rd',
#        'secondary_rd', 'distance', 'direction', 'weather_1', 'weather_2',
#        'collision_severity', 'type_of_collision', 'mviw', 'ped_action',
#        'road_surface', 'road_cond_1', 'road_cond_2', 'lighting',
#        'control_device', 'intersection', 'vz_pcf_code', 'vz_pcf_group',
#        'vz_pcf_description', 'vz_pcf_link', 'number_killed', 'number_injured',
#        'street_view', 'dph_col_grp', 'dph_col_grp_description',
#        'party_at_fault', 'party1_type', 'party1_dir_of_travel',
#        'party1_move_pre_acc', 'party2_type', 'party2_dir_of_travel',
# ...

# %%
df_selected=df[[
       'collision_datetime', 'collision_date', 'collision_time',
       'accident_year', 'month', 'day_of_week', 'time_cat',
       'secondary_rd', 'distance', 'direction', 'weather_1', 
       'collision_severity', 'type_of_collision', 'mviw', 'ped_action',
       'road_surface', 'road_cond_1', 'road_cond_2', 'lighting',
       'control_device', 'intersection', 'vz_pcf_code',  'number_killed', 'number_injured',
       'party_at_fault', 'party1_type', 'party1_dir_of_travel',
       'party1_move_pre_acc', 'party2_type', 'party2_dir_of_travel',
       'party2_move_pre_acc']]

# %%
df_selected.head()
# Out:
#        collision_datetime    collision_date collision_time  accident_year  \
# 0  01/18/2023 05:53:00 PM   2023 January 18       17:53:00           2023
# 1  02/15/2023 09:30:00 AM  2023 February 15       09:30:00           2023
# 2        11/11/2007 15:50  2007 November 11       15:50:00           2007
# 3  07/19/2019 01:50:00 PM      2019 July 19       13:50:00           2019
# 4        05/11/2017 07:53       2017 May 11       07:53:00           2017
#
#       month day_of_week             time_cat  secondary_rd  distance  \
# 0   January   Wednesday   2:01 pm to 6:00 pm   NEWCOMB AVE      68.0
# 1  February   Wednesday  6:01 am to 10:00 am     CHURCH ST      20.0
# 2  November      Sunday   2:01 pm to 6:00 pm     WALLER ST     210.0
# 3      July      Friday  10:01 am to 2:00 pm       04TH ST       0.0
# 4       May    Thursday  6:01 am to 10:00 am  VAN NESS AVE       0.0
#
#     direction  ... vz_pcf_code number_killed number_injured party_at_fault  \
# ...

# %%
df_selected.isna().sum()
# Out:
# collision_datetime         0
# collision_date             0
# collision_time            60
# accident_year              0
# month                      0
# day_of_week                9
# time_cat                  52
# secondary_rd             142
# distance                  79
# direction                  1
# weather_1                  0
# collision_severity         0
# type_of_collision          0
# mviw                       0
# ped_action                 0
# road_surface               0
# road_cond_1                0
# road_cond_2                0
# lighting                   0
# control_device             0
# intersection               1
# vz_pcf_code              346
# number_killed              3
# number_injured             0
# party_at_fault          6066
# party1_type               11
# party1_dir_of_travel      11
# party1_move_pre_acc       10
# party2_type             4386
# party2_dir_of_travel    4384
# party2_move_pre_acc     4383
# dtype: int64

# %%
df_selected['collision_time'].fillna(method='ffill',inplace=True)
df_selected
# Out:
# c:\Users\asaav\anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#            collision_datetime    collision_date collision_time  accident_year  \
# 0      01/18/2023 05:53:00 PM   2023 January 18       17:53:00           2023
# 1      02/15/2023 09:30:00 AM  2023 February 15       09:30:00           2023
# 2            11/11/2007 15:50  2007 November 11       15:50:00           2007
# 3      07/19/2019 01:50:00 PM      2019 July 19       13:50:00           2019
# 4            05/11/2017 07:53       2017 May 11       07:53:00           2017
# ...                       ...               ...            ...            ...
# 61224  07/29/2023 11:20:00 AM      2023 July 29       11:20:00           2023
# ...

# %%
df_selected.isna().sum()
# Out:
# collision_datetime         0
# collision_date             0
# collision_time             0
# accident_year              0
# month                      0
# day_of_week                9
# time_cat                  52
# secondary_rd             142
# distance                  79
# direction                  1
# weather_1                  0
# collision_severity         0
# type_of_collision          0
# mviw                       0
# ped_action                 0
# road_surface               0
# road_cond_1                0
# road_cond_2                0
# lighting                   0
# control_device             0
# intersection               1
# vz_pcf_code              346
# number_killed              3
# number_injured             0
# party_at_fault          6066
# party1_type               11
# party1_dir_of_travel      11
# party1_move_pre_acc       10
# party2_type             4386
# party2_dir_of_travel    4384
# party2_move_pre_acc     4383
# dtype: int64

# %%
import numpy as nd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_selected['collision_time'].value_counts()[0:5]
# Out:
# 18:00:00    290
# 16:00:00    273
# 14:00:00    272
# 15:00:00    261
# 14:30:00    244
# Name: collision_time, dtype: int64

# %%
df_selected['collision_time'].value_counts()
# Out:
# 18:00:00    290
# 16:00:00    273
# 14:00:00    272
# 15:00:00    261
# 14:30:00    244
#            ...
# 04:38:00      2
# 04:41:00      2
# 04:44:00      2
# 04:51:00      2
# 03:49:00      1
# Name: collision_time, Length: 1440, dtype: int64

# %%
for time in range (00:00:00,12:00:00):
    print("morning")
else:
    for time in range (12:01:00,17:00:00):
    print("Afternoon")
    else :
for time in range (17:01:00,19:00:00):
print("Evening")
elif:
for time in range (19:01:00,23:59:59):
print("Night")

# %%
df_selected['collision_time'].value_counts()[0:20].plot(kind='bar')
plt.title('collision_time')
plt.xlabel('collision_time')
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
df_selected['month'].value_counts()[0:20].plot(kind='bar')
plt.title('month')
plt.xlabel('month')
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
df_selected['day_of_week'].fillna(method='ffill',inplace=True)
df_selected
# Out:
# c:\Users\asaav\anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#            collision_datetime    collision_date collision_time  accident_year  \
# 0      01/18/2023 05:53:00 PM   2023 January 18       17:53:00           2023
# 1      02/15/2023 09:30:00 AM  2023 February 15       09:30:00           2023
# 2            11/11/2007 15:50  2007 November 11       15:50:00           2007
# 3      07/19/2019 01:50:00 PM      2019 July 19       13:50:00           2019
# 4            05/11/2017 07:53       2017 May 11       07:53:00           2017
# ...                       ...               ...            ...            ...
# 61224  07/29/2023 11:20:00 AM      2023 July 29       11:20:00           2023
# ...

# %%
df_selected.isna().sum()
# Out:
# collision_datetime         0
# collision_date             0
# collision_time             0
# accident_year              0
# month                      0
# day_of_week                9
# time_cat                  52
# secondary_rd             142
# distance                  79
# direction                  1
# weather_1                  0
# collision_severity         0
# type_of_collision          0
# mviw                       0
# ped_action                 0
# road_surface               0
# road_cond_1                0
# road_cond_2                0
# lighting                   0
# control_device             0
# intersection               1
# vz_pcf_code              346
# number_killed              3
# number_injured             0
# party_at_fault          6066
# party1_type               11
# party1_dir_of_travel      11
# party1_move_pre_acc       10
# party2_type             4386
# party2_dir_of_travel    4384
# party2_move_pre_acc     4383
# dtype: int64

# %%
df_selected['day_of_week'].value_counts()[0:20].plot(kind='bar')
plt.title('day_of_week')
plt.xlabel('day_of_week')
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')
